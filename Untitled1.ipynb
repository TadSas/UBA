# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import collections
import ast
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
df = pd.read_csv('../Data/Q2_2021.csv')

# %%
df['at'] = pd.to_datetime(df['at'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
Q2_2021 = df[(df['at'] >= '2021-04-01') & (df['at'] < '2021-07-01')]

# %%
# Q2_2021.reset_index(inplace = True, drop = True)

# %%
# Q2_2021.to_csv('../Data/Q2_2021.csv')

# %%
Q2_2021.groupby('account')['aim'].count().sort_values(ascending=False).head(170)
# Out:
# account
# 600.0    143196
# 402.0    128494
# 849.0    105988
# 428.0     89837
# 364.0     58652
#           ...
# 831.0      1049
# 383.0      1037
# 610.0      1022
# 768.0       980
# 171.0       976
# Name: aim, Length: 170, dtype: int64

# %%
user_df = Q2_2021[Q2_2021['account'] == 768].sort_values('at')
user_df.head()
# Out:
#        Unnamed: 0        id                   aim  account  roles  \
# 22496       22496  16292129                 login    768.0  {638}
# 22497       22497  16292130  auth_confirm_caution    768.0  {638}
# 31091       31091  16300050             open_task    768.0  {638}
# 31121       31121  16300083    download_task_file    768.0  {638}
# 32085       32085  16300916             open_task    768.0  {638}
#
#           remote_addr                                         user_agent  \
# 22496  91.221.229.138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 22497  91.221.229.138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 31091  91.221.229.138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 31121  91.221.229.138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 32085  91.221.229.138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#                                                      uri query_string  \
# 22496                                 /am/accounts/login          NaN
# 22497                            /am/accounts/login-info          NaN
# 31091                                   /am/tasks/410216          NaN
# 31121  /am/tasks/files/936698/9ddbd2692c056a7073165b0...          NaN
# 32085                                   /am/tasks/410216          NaN
#
#       request_method                                   referer succeeded  \
# 22496           POST               https://mul2-mss.gov.am/am/         t
# 22497            GET  https://mul2-mss.gov.am/am/login-caution         t
# 31091            GET      https://mul2-mss.gov.am/am/dashboard         t
# 31121            GET      https://mul2-mss.gov.am/am/dashboard         t
# 32085            GET      https://mul2-mss.gov.am/am/dashboard         t
#
#                               at  \
# 22496 2021-04-01 14:45:31.835062
# 22497 2021-04-01 14:45:32.273627
# 31091 2021-04-01 16:34:26.582591
# 31121 2021-04-01 16:34:55.738187
# 32085 2021-04-01 16:46:49.070475
#
#                                                   rights country_code
# 22496  {pa_plugin.pa_performance,permissions.see_all_...           am
# 22497  {pa_plugin.pa_performance,permissions.see_all_...           am
# 31091  {pa_plugin.pa_performance,permissions.see_all_...           am
# 31121  {pa_plugin.pa_performance,permissions.see_all_...           am
# 32085  {pa_plugin.pa_performance,permissions.see_all_...           am

# %%
label_encoder = LabelEncoder()
user_df['aim'] = label_encoder.fit_transform(user_df['aim'])
mapping = dict(zip(range(len(label_encoder.classes_)), label_encoder.classes_))
mapping
# Out:
# {0: 'apply_label',
#  1: 'attach_task_file',
#  2: 'auth_confirm_caution',
#  3: 'create_task',
#  4: 'download_task_file',
#  5: 'download_task_files',
#  6: 'login',
#  7: 'open_perform_action',
#  8: 'open_task',
#  9: 'perform_action',
#  10: 'token_login'}

# %%
# With repeat values
test = user_df['aim'].values.tolist()
accumulator = collections.Counter()
for length in range(1,len(test)+1):
    for start in range(len(test) - length):
        accumulator[str(test[start:start+length])] += 1

# %%
# Without repeat values
test = list(g[0] for g in itertools.groupby(user_df['aim'].values.tolist()))
accumulator = collections.Counter()
for length in range(1,len(test)+1):
    for start in range(len(test) - length):
        accumulator[str(test[start:start+length])] += 1

# %%
common_behaviour = []
for occ in sorted(list(set([(lambda x: x[1])(x) for x in accumulator.most_common()])), reverse=True):
    lst = list(filter(lambda x: x[1] == occ, accumulator.most_common()))
    if lst[0][1] == 1:
        continue
    lst = list(map(lambda x: (ast.literal_eval(x[0]), x[1]), lst))
    max_common = len(max(lst, key=lambda x: len(x[0]))[0])
    if max_common == 1:
        continue
    temp = list(filter(lambda x: len(x[0]) == max_common, lst))
    common_behaviour.extend(temp)
common_behaviour
# Out:
# [([8, 4], 113),
#  ([7, 9], 82),
#  ([4, 8], 80),
#  ([8, 4, 8], 79),
#  ([9, 8], 78),
#  ([8, 7], 78),
#  ([7, 9, 8], 64),
#  ([8, 7, 9], 63),
#  ([6, 2], 53),
#  ([2, 8], 49),
#  ([8, 7, 9, 8], 48),
#  ([6, 2, 8], 42),
#  ([8, 4, 8, 4], 39),
#  ([9, 8, 4], 34),
#  ([2, 8, 4], 33),
#  ([8, 4, 8, 7], 32),
#  ([8, 4, 8, 4, 8], 31),
#  ([8, 4, 8, 7, 9], 29),
#  ([7, 9, 8, 4], 28),
#  ([2, 8, 4, 8], 26),
#  ([8, 4, 8, 7, 9, 8], 24),
#  ([6, 2, 8, 4, 8], 23),
#  ([9, 8, 7, 9], 22),
#  ([8, 7, 9, 8, 4], 21),
#  ([7, 9, 8, 4, 8], 19),
#  ([9, 8, 7, 9, 8], 18),
#  ([8, 4, 8, 4, 8, 4], 17),
#  ([2, 8, 4, 8, 4], 16),
#  ([8, 4, 7, 9, 8], 16),
#  ([8, 6, 2, 8], 15),
#  ([6, 2, 8, 4, 8, 4], 14),
#  ([8, 7, 9, 8, 7, 9], 14),
#  ([8, 4, 8, 4, 8, 4, 8], 13),
#  ([8, 4, 8, 4, 8, 7, 9], 12),
#  ([8, 4, 8, 4, 8, 7, 9, 8], 11),
#  ([8, 4, 8, 4, 8, 4, 8, 4], 11),
#  ([2, 8, 4, 8, 7, 9], 10),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8], 9),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 8),
#  ([6, 2, 8, 4, 8, 4, 8, 7, 9, 8], 7),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 6),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 5),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 4),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 3),
#  ([8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4], 2)]

# %%
def subfinder(mylist, pattern):
    matches = []
    for i in range(len(mylist)):
        if mylist[i] == pattern[0] and mylist[i:i+len(pattern)] == pattern:
            matches.append(pattern)
    return matches

# %%
len(subfinder(test, [7, 2, 7, 6, 0, 0, 8, 7, 6, 8, 7, 5, 4, 1, 7]))
# Out:
# 3

# %%
for pttrn in common_behaviour:
#     print(f"This pattern occurred {pttrn[1]} times")
#     print("The pattern is:\n\t| ", end="")
    print(list(itertools.groupby(list(map(lambda x: mapping[x], pttrn[0])))))
#     for g in itertools.groupby(list(map(lambda x: mapping[x], pttrn[0]))):
#         occ = len(list(g[1]))
#         if occ == 1:
#             print(f"{g[0]}", " -> ", end="", sep="")
#         else:
#             print(f"{occ}x {g[0]}", " -> ", end="", sep="")
#     print("|")
    print()
# Out:
# [('open_task', <itertools._grouper object at 0x0000019D3CB72550>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB72280>)]
#
# [('open_perform_action', <itertools._grouper object at 0x0000019D3CB72340>), ('perform_action', <itertools._grouper object at 0x0000019D3CB74430>)]
#
# [('download_task_file', <itertools._grouper object at 0x0000019D3CB74430>), ('open_task', <itertools._grouper object at 0x0000019D3CB743D0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB74430>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB74F10>), ('open_task', <itertools._grouper object at 0x0000019D3CB74700>)]
#
# [('perform_action', <itertools._grouper object at 0x0000019D3CB743D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB749A0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB74F10>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB74F40>)]
#
# [('open_perform_action', <itertools._grouper object at 0x0000019D3CB749A0>), ('perform_action', <itertools._grouper object at 0x0000019D3CB74070>), ('open_task', <itertools._grouper object at 0x0000019D3CB742B0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB74F40>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB74400>), ('perform_action', <itertools._grouper object at 0x0000019D3CB741C0>)]
#
# [('login', <itertools._grouper object at 0x0000019D3CB74070>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB74DC0>)]
#
# [('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB74400>), ('open_task', <itertools._grouper object at 0x0000019D3CB74550>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB74DC0>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB74A90>), ('perform_action', <itertools._grouper object at 0x0000019D3CB74FD0>), ('open_task', <itertools._grouper object at 0x0000019D3CB74850>)]
#
# [('login', <itertools._grouper object at 0x0000019D3CB74A90>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB74D00>), ('open_task', <itertools._grouper object at 0x0000019D3CB65040>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB74FD0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65040>), ('open_task', <itertools._grouper object at 0x0000019D3CB65E80>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65400>)]
#
# [('perform_action', <itertools._grouper object at 0x0000019D3CB65040>), ('open_task', <itertools._grouper object at 0x0000019D3CB65C70>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65550>)]
#
# [('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB65E80>), ('open_task', <itertools._grouper object at 0x0000019D3CB651C0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65460>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB65C70>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65460>), ('open_task', <itertools._grouper object at 0x0000019D3CB65790>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB65BE0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB65460>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB65BE0>), ('open_task', <itertools._grouper object at 0x0000019D3CB65A00>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB657C0>), ('open_task', <itertools._grouper object at 0x0000019D3CB65370>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB65BE0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB657C0>), ('open_task', <itertools._grouper object at 0x0000019D3CB65370>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB65490>), ('perform_action', <itertools._grouper object at 0x0000019D296900D0>)]
#
# [('open_perform_action', <itertools._grouper object at 0x0000019D3CB657C0>), ('perform_action', <itertools._grouper object at 0x0000019D3CB65490>), ('open_task', <itertools._grouper object at 0x0000019D296900D0>), ('download_task_file', <itertools._grouper object at 0x0000019D296905E0>)]
#
# [('auth_confirm_caution', <itertools._grouper object at 0x0000019D296900D0>), ('open_task', <itertools._grouper object at 0x0000019D296905E0>), ('download_task_file', <itertools._grouper object at 0x0000019D29690430>), ('open_task', <itertools._grouper object at 0x0000019D29690D90>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D296905E0>), ('download_task_file', <itertools._grouper object at 0x0000019D29690D90>), ('open_task', <itertools._grouper object at 0x0000019D296903A0>), ('open_perform_action', <itertools._grouper object at 0x0000019D29690370>), ('perform_action', <itertools._grouper object at 0x0000019D296903D0>), ('open_task', <itertools._grouper object at 0x0000019D29690040>)]
#
# [('login', <itertools._grouper object at 0x0000019D29690D90>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D29690370>), ('open_task', <itertools._grouper object at 0x0000019D296903D0>), ('download_task_file', <itertools._grouper object at 0x0000019D29690040>), ('open_task', <itertools._grouper object at 0x0000019D29690130>)]
#
# [('perform_action', <itertools._grouper object at 0x0000019D29690370>), ('open_task', <itertools._grouper object at 0x0000019D29690040>), ('open_perform_action', <itertools._grouper object at 0x0000019D29690130>), ('perform_action', <itertools._grouper object at 0x0000019D296901F0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D29690040>), ('open_perform_action', <itertools._grouper object at 0x0000019D296901F0>), ('perform_action', <itertools._grouper object at 0x0000019D29690F10>), ('open_task', <itertools._grouper object at 0x0000019D29690A30>), ('download_task_file', <itertools._grouper object at 0x0000019D29690580>)]
#
# [('open_perform_action', <itertools._grouper object at 0x0000019D296901F0>), ('perform_action', <itertools._grouper object at 0x0000019D29690A30>), ('open_task', <itertools._grouper object at 0x0000019D29690580>), ('download_task_file', <itertools._grouper object at 0x0000019D29690310>), ('open_task', <itertools._grouper object at 0x0000019D29690A00>)]
#
# [('perform_action', <itertools._grouper object at 0x0000019D29690A30>), ('open_task', <itertools._grouper object at 0x0000019D29690310>), ('open_perform_action', <itertools._grouper object at 0x0000019D29690A00>), ('perform_action', <itertools._grouper object at 0x0000019D29690F70>), ('open_task', <itertools._grouper object at 0x0000019D29690880>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D29690310>), ('download_task_file', <itertools._grouper object at 0x0000019D29690F70>), ('open_task', <itertools._grouper object at 0x0000019D29690880>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A040>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A7F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A970>)]
#
# [('auth_confirm_caution', <itertools._grouper object at 0x0000019D29690F70>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A040>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A7F0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A970>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7AF40>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7A040>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A970>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB7AF40>), ('perform_action', <itertools._grouper object at 0x0000019D3CB7A820>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A7C0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7A970>), ('login', <itertools._grouper object at 0x0000019D3CB7A820>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB7A7C0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A220>)]
#
# [('login', <itertools._grouper object at 0x0000019D3CB7A820>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB7A220>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A160>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A460>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A700>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7AD30>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7A220>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB7A460>), ('perform_action', <itertools._grouper object at 0x0000019D3CB7A700>), ('open_task', <itertools._grouper object at 0x0000019D3CB7AD30>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB7AE80>), ('perform_action', <itertools._grouper object at 0x0000019D3CB7AE20>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7A460>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7AD30>), ('open_task', <itertools._grouper object at 0x0000019D3CB7AE80>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7AE20>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A850>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A0A0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A9A0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7AD30>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7AE20>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A850>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A0A0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A9A0>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB7A2E0>), ('perform_action', <itertools._grouper object at 0x0000019D3CB7A6D0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7AE20>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A0A0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A9A0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A2E0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A6D0>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB69850>), ('perform_action', <itertools._grouper object at 0x0000019D3CB69DC0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69A00>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB7A0A0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB7A2E0>), ('open_task', <itertools._grouper object at 0x0000019D3CB7A6D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69850>), ('open_task', <itertools._grouper object at 0x0000019D3CB69DC0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69A00>), ('open_task', <itertools._grouper object at 0x0000019D3CB69640>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69490>)]
#
# [('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB7A2E0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69850>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69DC0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69A00>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB69640>), ('perform_action', <itertools._grouper object at 0x0000019D3CB69490>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69850>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69A00>), ('open_task', <itertools._grouper object at 0x0000019D3CB69640>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69490>), ('open_task', <itertools._grouper object at 0x0000019D3CB69370>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69280>), ('open_task', <itertools._grouper object at 0x0000019D3CB698E0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69460>), ('open_task', <itertools._grouper object at 0x0000019D3CB69AC0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69A00>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69490>), ('open_task', <itertools._grouper object at 0x0000019D3CB69370>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69280>), ('open_task', <itertools._grouper object at 0x0000019D3CB698E0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69460>), ('open_task', <itertools._grouper object at 0x0000019D3CB69AC0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69BB0>), ('open_task', <itertools._grouper object at 0x0000019D3CB692B0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB691F0>)]
#
# [('login', <itertools._grouper object at 0x0000019D3CB69490>), ('auth_confirm_caution', <itertools._grouper object at 0x0000019D3CB69280>), ('open_task', <itertools._grouper object at 0x0000019D3CB698E0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69460>), ('open_task', <itertools._grouper object at 0x0000019D3CB69AC0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69BB0>), ('open_task', <itertools._grouper object at 0x0000019D3CB692B0>), ('open_perform_action', <itertools._grouper object at 0x0000019D3CB691F0>), ('perform_action', <itertools._grouper object at 0x0000019D3CB69220>), ('open_task', <itertools._grouper object at 0x0000019D3CB69CA0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69280>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69460>), ('open_task', <itertools._grouper object at 0x0000019D3CB69AC0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69BB0>), ('open_task', <itertools._grouper object at 0x0000019D3CB692B0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB691F0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69220>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69CA0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69D90>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69430>), ('open_task', <itertools._grouper object at 0x0000019D3CB693D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB696D0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69460>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69BB0>), ('open_task', <itertools._grouper object at 0x0000019D3CB692B0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB691F0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69220>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69CA0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69D90>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69430>), ('open_task', <itertools._grouper object at 0x0000019D3CB693D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB696D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69BE0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B50>), ('open_task', <itertools._grouper object at 0x0000019D3CB694F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69C40>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69BB0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB691F0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69220>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69CA0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69D90>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69430>), ('open_task', <itertools._grouper object at 0x0000019D3CB693D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB696D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69BE0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B50>), ('open_task', <itertools._grouper object at 0x0000019D3CB694F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69C40>), ('open_task', <itertools._grouper object at 0x0000019D3CB69FD0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69EE0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69C10>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB690D0>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB69BB0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB691F0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69220>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69CA0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69D90>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69430>), ('open_task', <itertools._grouper object at 0x0000019D3CB693D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB696D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69BE0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B50>), ('open_task', <itertools._grouper object at 0x0000019D3CB694F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69C40>), ('open_task', <itertools._grouper object at 0x0000019D3CB69FD0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69EE0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69C10>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB690D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69E20>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B80>)]
#
# [('open_task', <itertools._grouper object at 0x0000019D3CB691F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69CA0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69D90>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69430>), ('open_task', <itertools._grouper object at 0x0000019D3CB693D0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB696D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69BE0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B50>), ('open_task', <itertools._grouper object at 0x0000019D3CB694F0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69C40>), ('open_task', <itertools._grouper object at 0x0000019D3CB69FD0>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69EE0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69C10>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB690D0>), ('open_task', <itertools._grouper object at 0x0000019D3CB69E20>), ('download_task_file', <itertools._grouper object at 0x0000019D3CB69B80>), ('open_task', <itertools._grouper object at 0x0000019D29593DC0>), ('download_task_file', <itertools._grouper object at 0x0000019D29593CD0>), ('open_task', <itertools._grouper object at 0x0000019D295933D0>), ('download_task_file', <itertools._grouper object at 0x0000019D29593AF0>)]

# %%
for pttrn in common_behaviour:
    print(f"This pattern occurred {pttrn[1]} times")
    print("The pattern is:")
    print('|', ' -> '.join(list(map(lambda x: mapping[x], pttrn[0]))), '|')
    print()
# Out:
# This pattern occurred 113 times
# The pattern is:
# | open_task -> download_task_file |
#
# This pattern occurred 82 times
# The pattern is:
# | open_perform_action -> perform_action |
#
# This pattern occurred 80 times
# The pattern is:
# | download_task_file -> open_task |
#
# This pattern occurred 79 times
# The pattern is:
# | open_task -> download_task_file -> open_task |
#
# This pattern occurred 78 times
# The pattern is:
# | perform_action -> open_task |
#
# This pattern occurred 78 times
# The pattern is:
# | open_task -> open_perform_action |
#
# This pattern occurred 64 times
# The pattern is:
# | open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 63 times
# The pattern is:
# | open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 53 times
# The pattern is:
# | login -> auth_confirm_caution |
#
# This pattern occurred 49 times
# The pattern is:
# | auth_confirm_caution -> open_task |
#
# This pattern occurred 48 times
# The pattern is:
# | open_task -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 42 times
# The pattern is:
# | login -> auth_confirm_caution -> open_task |
#
# This pattern occurred 39 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 34 times
# The pattern is:
# | perform_action -> open_task -> download_task_file |
#
# This pattern occurred 33 times
# The pattern is:
# | auth_confirm_caution -> open_task -> download_task_file |
#
# This pattern occurred 32 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> open_perform_action |
#
# This pattern occurred 31 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 29 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 28 times
# The pattern is:
# | open_perform_action -> perform_action -> open_task -> download_task_file |
#
# This pattern occurred 26 times
# The pattern is:
# | auth_confirm_caution -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 24 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 23 times
# The pattern is:
# | login -> auth_confirm_caution -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 22 times
# The pattern is:
# | perform_action -> open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 21 times
# The pattern is:
# | open_task -> open_perform_action -> perform_action -> open_task -> download_task_file |
#
# This pattern occurred 19 times
# The pattern is:
# | open_perform_action -> perform_action -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 18 times
# The pattern is:
# | perform_action -> open_task -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 17 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 16 times
# The pattern is:
# | auth_confirm_caution -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 16 times
# The pattern is:
# | open_task -> download_task_file -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 15 times
# The pattern is:
# | open_task -> login -> auth_confirm_caution -> open_task |
#
# This pattern occurred 14 times
# The pattern is:
# | login -> auth_confirm_caution -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 14 times
# The pattern is:
# | open_task -> open_perform_action -> perform_action -> open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 13 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 12 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 11 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 11 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 10 times
# The pattern is:
# | auth_confirm_caution -> open_task -> download_task_file -> open_task -> open_perform_action -> perform_action |
#
# This pattern occurred 9 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task |
#
# This pattern occurred 8 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 7 times
# The pattern is:
# | login -> auth_confirm_caution -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> open_perform_action -> perform_action -> open_task |
#
# This pattern occurred 6 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 5 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 4 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 3 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |
#
# This pattern occurred 2 times
# The pattern is:
# | open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file -> open_task -> download_task_file |

# %%
pat = np.asarray([7, 6, 0, 0, 8, 7, 6])
N = len(pat)


user_df['pattern'] = (user_df['aim'].rolling(window=N , min_periods=N)
                          .apply(lambda x: (x==pat).all())
                          .mask(lambda x: x == 0) 
                          .bfill(limit=N-1)
                          .fillna(0)
                          .astype(bool)
             )
user_df[user_df['pattern'] == True].replace({'aim': mapping})
# Out:
#                 id                  aim  account roles     remote_addr  \
# 14232025  14265956            open_task     56.0  {55}  212.42.195.154
# 14232115  14265959  open_perform_action     56.0  {55}  212.42.195.154
# 14232013  14265963     attach_task_file     56.0  {55}  212.42.195.154
# 14232084  14265967     attach_task_file     56.0  {55}  212.42.195.154
# 14232126  14266041       perform_action     56.0  {55}  212.42.195.154
# ...            ...                  ...      ...   ...             ...
# 16282152  16316690     attach_task_file     56.0  {55}  212.42.195.154
# 16282228  16316770     attach_task_file     56.0  {55}  212.42.195.154
# 16282223  16316790       perform_action     56.0  {55}  212.42.195.154
# 16282280  16316799            open_task     56.0  {55}  212.42.195.154
# 16282102  16316802  open_perform_action     56.0  {55}  212.42.195.154
#
#                                                  user_agent  \
# 14232025  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 14232115  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 14232013  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 14232084  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 14232126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# ...                                                     ...
# 16282152  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 16282228  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 16282223  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 16282280  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 16282102  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
#
#                                           uri query_string request_method  \
# 14232025                     /am/tasks/386104          NaN            GET
# 14232115          /am/tasks/386104/action/585          NaN            GET
# 14232013                     /am/tasks/attach          NaN           POST
# 14232084                     /am/tasks/attach          NaN           POST
# 14232126  /am/tasks/386104/perform-action/585          NaN           POST
# ...                                       ...          ...            ...
# 16282152                     /am/tasks/attach          NaN           POST
# 16282228                     /am/tasks/attach          NaN           POST
# 16282223  /am/tasks/437682/perform-action/585          NaN           POST
# 16282280                     /am/tasks/437682          NaN            GET
# 16282102          /am/tasks/437682/action/564          NaN            GET
#
#                                        referer succeeded  \
# 14232025  https://mul2-mss.gov.am/am/dashboard         t
# 14232115  https://mul2-mss.gov.am/am/dashboard         t
# 14232013  https://mul2-mss.gov.am/am/dashboard         t
# 14232084  https://mul2-mss.gov.am/am/dashboard         t
# 14232126  https://mul2-mss.gov.am/am/dashboard         t
# ...                                        ...       ...
# 16282152  https://mul2-mss.gov.am/am/dashboard         t
# 16282228  https://mul2-mss.gov.am/am/dashboard         t
# 16282223  https://mul2-mss.gov.am/am/dashboard         t
# 16282280  https://mul2-mss.gov.am/am/dashboard         t
# 16282102  https://mul2-mss.gov.am/am/dashboard         t
#
#                                  at  \
# 14232025 2021-01-21 12:05:37.990084
# 14232115 2021-01-21 12:05:41.653728
# 14232013 2021-01-21 12:05:48.031024
# 14232084 2021-01-21 12:05:51.073253
# 14232126 2021-01-21 12:07:10.862153
# ...                             ...
# 16282152 2021-04-02 10:50:03.090730
# 16282228 2021-04-02 10:51:23.774164
# 16282223 2021-04-02 10:51:42.839475
# 16282280 2021-04-02 10:51:48.895937
# 16282102 2021-04-02 10:51:52.717345
#
#                                                      rights country_code  \
# 14232025  {pa_plugin.pa_performance,permissions.see_all_...           am
# 14232115  {pa_plugin.pa_performance,permissions.see_all_...           am
# 14232013  {pa_plugin.pa_performance,permissions.see_all_...           am
# 14232084  {pa_plugin.pa_performance,permissions.see_all_...           am
# 14232126  {pa_plugin.pa_performance,permissions.see_all_...           am
# ...                                                     ...          ...
# 16282152  {pa_plugin.pa_performance,permissions.see_all_...           am
# 16282228  {pa_plugin.pa_performance,permissions.see_all_...           am
# 16282223  {pa_plugin.pa_performance,permissions.see_all_...           am
# 16282280  {pa_plugin.pa_performance,permissions.see_all_...           am
# 16282102  {pa_plugin.pa_performance,permissions.see_all_...           am
#
#           pattern
# 14232025     True
# 14232115     True
# 14232013     True
# 14232084     True
# 14232126     True
# ...           ...
# 16282152     True
# 16282228     True
# 16282223     True
# 16282280     True
# 16282102     True
#
# [91 rows x 15 columns]

# %%
import itertools

# %%
text = 'hiiii how are you??'
exp = [1, 2, 2, 2, 5, 7, 4, 4, 4, 6]
